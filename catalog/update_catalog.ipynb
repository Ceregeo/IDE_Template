# %% [markdown]
# <a href="https://colab.research.google.com/github/Ceregeo/IDE_Template/blob/main/catalog/update_catalog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title String fields

text = 'value' #@param {type:"string"}
titulo = "mapa de cultivos de entre rios" #@param {type:"string"}

# %%
#@title
templ = {
    "stac_version": "1.0.0",
    "type": "Collection",
    "stac_extensions": [
        "https://stac-extensions.github.io/eo/v1.0.0/schema.json"
    ],
    "id": "IDE-FCyT/IDE-FCyT/main/catalog/SuelosER.json",
    "title": titulo
,
    "description": "Carta de Suelo ER - INTA",
    "license": "CC-BY-4.0",
    "gee:type": "vector",
    "links": [
        {
            "rel": "self",
            "href": "https://raw.githubusercontent.com/IDE-FCyT/IDE-FCyT/main/catalog/SuelosER.json",
            "type": "application/json"
        },
        {
            "rel": "parent",
            "href": "https://raw.githubusercontent.com/IDE-FCyT/IDE-FCyT/main/catalog/stac_catalog.json",
            "type": "application/json"
        },
        {
            "rel": "root",
            "href": "https://raw.githubusercontent.com/IDE-FCyT/IDE-FCyT/main/catalog/stac_catalog.json",
            "type": "application/json"
        },
        {
            "title": "Carta de Suelos de la Provincia de Entre Ríos",
            "rel": "related",
            "href": "https://ftentoru.users.earthengine.app/view/cartasueloser",
            "type": "text/html",
            "code": "JavaScript"
        },
        {
            "href": "https://raw.githubusercontent.com/IDE-FCyT/IDE-FCyT/main/images/Captura_cartaER.png",
            "rel": "preview",
            "type": "image/png"
         },
        {
            "rel": "license",
            "href": "https://raw.githubusercontent.com/IDE-FCyT/IDE-FCyT/main/LICENSE"
        }
    ],
    "extent": {
        "spatial": {
            "bbox": [
                [
                    -61.0648,
                    -34.15252,
                    -57.54923,
                    -29.93567
                ]
            ]
        },
        "temporal": {
            "interval": [
                [
                    "2021-07-21T05:31:04.396719Z",
                    "2021-07-21T05:31:04.396719Z"
                ]
            ]
        }
    },
    "properties": {
        "datetime": "2018-06-05T10:00:27Z",
        "gsdo": 10,
        "proj:epsg": 4326},
    "gee:terms_of_use": "This dataset is made available publicly under CC-BY-4.0.",
    "gee:user_uploaded": True,
    "keywords": [
        "Soil grid, Entre Rios, Soil, Coarse"
    ],
    "providers": [
        {
            "name": "INTA",
            "roles": [
                "producer",
                "licensor"
            ]
        },
        {
            "name": "Centro Regional de Geomática",
            "roles": [
                "processor"
            ]
        },
        {
            "name": "Fernando Tentor",
            "roles": [
                "processor"
            ]
        },
        {
            "name": "Noeli Baeza",
            "roles": [
                "processor"
            ]
        },
        {
            "name": "Facundo Boladera",
            "roles": [
                "processor"
            ]
        }
    ]
}

# %%
display(templ)
# Out:
# {'stac_version': '1.0.0',
#  'type': 'Collection',
#  'stac_extensions': ['https://stac-extensions.github.io/eo/v1.0.0/schema.json'],
#  'id': 'IDE-FCyT/IDE-FCyT/main/catalog/SuelosER.json',
#  'title': 'mapa de cultivos de entre rios',
#  'description': 'Carta de Suelo ER - INTA',
#  'license': 'CC-BY-4.0',
#  'gee:type': 'vector',
#  'links': [{'rel': 'self',
#    'href': 'https://raw.githubusercontent.com/IDE-FCyT/IDE-FCyT/main/catalog/SuelosER.json',
#    'type': 'application/json'},
#   {'rel': 'parent',
#    'href': 'https://raw.githubusercontent.com/IDE-FCyT/IDE-FCyT/main/catalog/stac_catalog.json',
#    'type': 'application/json'},
#   {'rel': 'root',
#    'href': 'https://raw.githubusercontent.com/IDE-FCyT/IDE-FCyT/main/catalog/stac_catalog.json',
#    'type': 'application/json'},
#   {'title': 'Carta de Suelos de la Provincia de Entre Ríos',
#    'rel': 'related',
#    'href': 'https://ftentoru.users.earthengine.app/view/cartasueloser',
#    'type': 'text/html',
# ...
